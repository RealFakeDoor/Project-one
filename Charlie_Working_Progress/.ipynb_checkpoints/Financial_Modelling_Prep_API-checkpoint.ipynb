# %%
from pprint import pprint
import requests

api_key = 'apikey=VI8Ta4kXzXofj5D5utQFSgtNViJBWnFb'
Ticker = 'AAPL'

# %%
# Retrieves the current Market data on the stock from the API:
    # Stock Price, Beta, Average Volume ETC.
Company_Profile_ENDPOINT = 'https://financialmodelingprep.com/api/v3/profile/'

url = f'{Company_Profile_ENDPOINT}{Ticker}?{api_key}'

response = requests.get(url).json()
response

# %%
#  Returns the opening price, high price, low price, and closing price of the company's stock for each day in a specified date range. 
#  By default the limit is 5 years of historical data, to get data prior to this date, please use the to & from parameters with a limit of 5 years.
Ticker = 'VAS'

Daily_Historial_Price_API = 'https://financialmodelingprep.com/api/v3/historical-price-full/'
# from    date    2023-10-10
# to      date    2023-12-10

url = f'{Daily_Historial_Price_API}{Ticker}?{api_key}'

response = requests.get(url).json()
response
# Out:
# {}

# %%
# Retrieves the last five years of Income statements from the API.
Income_Statement_Endpoint ='https://financialmodelingprep.com/api/v3/income-statement/'

period = 'period=annual'

url = f'{Income_Statement_Endpoint}{Ticker}?{period}&{api_key}'

response = requests.get(url).json()
response
# Out:
# [{'date': '2023-09-30',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2023-11-03',
#   'acceptedDate': '2023-11-02 18:08:27',
#   'calendarYear': '2023',
#   'period': 'FY',
#   'revenue': 383285000000,
#   'costOfRevenue': 214137000000,
#   'grossProfit': 169148000000,
#   'grossProfitRatio': 0.4413112958,
#   'researchAndDevelopmentExpenses': 29915000000,
#   'generalAndAdministrativeExpenses': 0,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 24932000000,
#   'otherExpenses': -565000000,
#   'operatingExpenses': 54847000000,
#   'costAndExpenses': 268984000000,
#   'interestIncome': 3750000000,
#   'interestExpense': 3933000000,
#   'depreciationAndAmortization': 11519000000,
#   'ebitda': 125820000000,
#   'ebitdaratio': 0.3282674772,
#   'operatingIncome': 114301000000,
#   'operatingIncomeRatio': 0.2982141227,
#   'totalOtherIncomeExpensesNet': -565000000,
# ...

# %%
# Gets the Historical Dividend payments for a stock.

Historical_Dividend_Endpoint = 'https://financialmodelingprep.com/api/v3/historical-price-full/stock_dividend/'

url = f'{Historical_Dividend_Endpoint}{Ticker}?{api_key}'

response = requests.get(url).json()
response
# Out:
# {'symbol': 'AAPL',
#  'historical': [{'date': '2024-02-09',
#    'label': 'February 09, 24',
#    'adjDividend': 0.24,
#    'dividend': 0.24,
#    'recordDate': '2024-02-12',
#    'paymentDate': '2024-02-15',
#    'declarationDate': '2024-02-01'},
#   {'date': '2023-11-10',
#    'label': 'November 10, 23',
#    'adjDividend': 0.24,
#    'dividend': 0.24,
#    'recordDate': '2023-11-13',
#    'paymentDate': '2023-11-16',
#    'declarationDate': '2023-11-02'},
#   {'date': '2023-08-11',
#    'label': 'August 11, 23',
#    'adjDividend': 0.24,
#    'dividend': 0.24,
#    'recordDate': '2023-08-14',
#    'paymentDate': '2023-08-17',
#    'declarationDate': '2023-08-03'},
#   {'date': '2023-05-12',
#    'label': 'May 12, 23',
#    'adjDividend': 0.24,
#    'dividend': 0.24,
#    'recordDate': '2023-05-15',
#    'paymentDate': '2023-05-18',
#    'declarationDate': '2023-05-04'},
#   {'date': '2023-02-10',
#    'label': 'February 10, 23',
#    'adjDividend': 0.23,
#    'dividend': 0.23,
# ...

# %%
GDP_Endpoint = "https://financialmodelingprep.com/api/v4/economic?name=GDP"


url = f'{GDP_Endpoint}&{api_key}'

response = requests.get(url).json()
response
# from           # to
# date           # date
# 2019-10-10     # 2021-11-10
# Out:
# {'Error Message': 'Special Endpoint : This endpoint is not available under your current subscription please visit our subscription page to upgrade your plan at https://site.financialmodelingprep.com/developer/docs/pricing'}

# %%
Treasury_Rate_Endpoint = "https://financialmodelingprep.com/api/v4/treasury?from=2023-08-10&to=2023-10-10"

# Parameters:

# from
# date
# 2019-10-10

# to
# date
# 2021-11-10

# %%
Financial_Health_Endpoint = 'https://financialmodelingprep.com/api/v4/score?symbol=AAPL'

# [
# 	{
# 		"symbol": "AAPL",
# 		"altmanZScore": 8.218706082381152,
# 		"piotroskiScore": 8,
# 		"workingCapital": -2304000000,
# 		"totalAssets": 335038000000,
# 		"retainedEarnings": 1408000000,
# 		"ebit": 109174000000,
# 		"marketCap": 2747554229268,
# 		"totalLiabilities": 274764000000,
# 		"revenue": 383933000000
# 	}
# ]

# %%
# Out:
# {'symbol': 'AAPL',
#  'historical': [{'date': '2024-02-09',
#    'label': 'February 09, 24',
#    'adjDividend': 0.24,
#    'dividend': 0.24,
#    'recordDate': '2024-02-12',
#    'paymentDate': '2024-02-15',
#    'declarationDate': '2024-02-01'},
#   {'date': '2023-11-10',
#    'label': 'November 10, 23',
#    'adjDividend': 0.24,
#    'dividend': 0.24,
#    'recordDate': '2023-11-13',
#    'paymentDate': '2023-11-16',
#    'declarationDate': '2023-11-02'},
#   {'date': '2023-08-11',
#    'label': 'August 11, 23',
#    'adjDividend': 0.24,
#    'dividend': 0.24,
#    'recordDate': '2023-08-14',
#    'paymentDate': '2023-08-17',
#    'declarationDate': '2023-08-03'},
#   {'date': '2023-05-12',
#    'label': 'May 12, 23',
#    'adjDividend': 0.24,
#    'dividend': 0.24,
#    'recordDate': '2023-05-15',
#    'paymentDate': '2023-05-18',
#    'declarationDate': '2023-05-04'},
#   {'date': '2023-02-10',
#    'label': 'February 10, 23',
#    'adjDividend': 0.23,
#    'dividend': 0.23,
# ...
