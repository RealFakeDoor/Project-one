# %%
from pprint import pprint
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

# %%
path = 'Total_FED_CYCLE.csv'

df_Total_FED_CYCLE = pd.read_csv(path)

# %%
path = 'FED_FUND_RATE_TOTAL.csv'

FED_FUND_RATE_TOTAL = pd.read_csv(path)

# %%
# Out:
#           date  Federal Fund Rate Target
# 0   2003-01-01                      1.24
# 1   2003-01-02                      1.26
# 2   2003-01-03                      1.25
# 3   2003-01-04                      1.26
# 4   2003-01-05                      1.26
# ..         ...                       ...
# 80  2009-01-09                      0.15
# 81  2009-01-10                      0.12
# 82  2009-01-11                      0.12
# 83  2009-01-12                      0.12
# 84  2010-01-01                      0.11
#
# [85 rows x 2 columns]

# %%
# Set 'Date' column as the index
df_Total_FED_CYCLE.set_index('Date', inplace=True)

# %%
# Calculate ROI for each column
df_roi = roi_df = df_Total_FED_CYCLE / df_Total_FED_CYCLE.iloc[0] - 1
# Calculate percentage change as ROI

# Plot the DataFrame with ROI values
df_roi.plot(kind='line', figsize=(10, 6))

# Add horizontal line at y=0
plt.axhline(y=0, color='k', linestyle='--')

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Daily ROI (%)')
plt.title('Sectors ROI Over the Entire Period')

# Show the plot
plt.show()

# %%
path = 'Sector_data_complete.csv'

df_sector_data_complete = pd.read_csv(path)

# %%
# Calculate ROI for each column
df_roi = roi_df = df_sector_data_complete / df_sector_data_complete.iloc[0] - 1
# Calculate percentage change as ROI

# Plot the DataFrame with ROI values
df_roi.plot(kind='line', figsize=(10, 6))

# Add horizontal line at y=0
plt.axhline(y=0, color='k', linestyle='--')

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Daily ROI (%)')
plt.title('Line Graph of DataFrame Columns as ROI')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:220, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 try:
# --> 220     result = func(left, right)
#     221 except TypeError:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:131, in _evaluate_numexpr(op, op_str, a, b)
#     130 if result is None:
# --> 131     result = _evaluate_standard(op, op_str, a, b)
#     133 return result
#
# ...
